# %%
import pandas as pd

# %% [markdown]
# # Q1

# %%
# Done

# %% [markdown]
# # Q2

# %%
df = pd.read_csv(r'C:\Users\dell\Desktop\heart.csv')

print("First 20 rows:")
print(df.head(20))

print("\nData description:")
print(df.describe())
# Out:
# First 20 rows:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   3       145   233    1        0      150      0      2.3
# 1    37    1   2       130   250    0        1      187      0      3.5
# 2    41    0   1       130   204    0        0      172      0      1.4
# 3    56    1   1       120   236    0        1      178      0      0.8
# 4    57    0   0       120   354    0        1      163      1      0.6
# 5    57    1   0       140   192    0        1      148      0      0.4
# 6    56    0   1       140   294    0        0      153      0      1.3
# 7    44    1   1       120   263    0        1      173      0      0.0
# 8    52    1   2       172   199    1        1      162      0      0.5
# 9    57    1   2       150   168    0        1      174      0      1.6
# 10   54    1   0       140   239    0        1      160      0      1.2
# 11   48    0   2       130   275    0        1      139      0      0.2
# ...

# %% [markdown]
# # Q3

# %%
print(df.shape)
# Out:
# (303, 14)

# %% [markdown]
# # Q4

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 12, 5, 8, 9]

plt.plot(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y = [10, 12, 5, 8, 9]

plt.bar(x, y)
plt.show()

# %%
x = [1, 2, 3, 4, 5]

# Create a pie chart
plt.pie(x)
plt.title('Pie Chart Example')
plt.show()

# %% [markdown]
# # Q5

# %%
# you are just describing a hear desease from the given scv file data:
# Represents the age of an individuals 
# the gender of an individual 0 for femail 1 for male
#CP : Chest Pain Type 
#trestbps : Represents the resting blood pressure of the individual
# chol: Indicates the cholesterol level of the individual 
#restecg: Describes the results of the resting electrocardiogram
#thalach: Represents the maximum heart rate achieved during the exercise test
#exang: Indicates whether the individual experiences exercise-induced angina or not
#oldpeak: Represents the ST depression induced by exercise relative to rest
#slope: Describes the slope of the peak exercise ST segment
#ca: Represents the number of major vessels colored by fluoroscopy
#thal: Represents a blood disorder called thalassemia
#target: Typically used in a binary classification context as 1 means presence of a heart disease but 0 indicate the absence
